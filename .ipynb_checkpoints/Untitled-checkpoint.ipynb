# %% [markdown]
# MariaDB (= MySQL)
# Oracle
# MS-SQL
#
# =======> SQL (Structured Query Language)
#         ANSI SQL
#
# WebServer(Spring) <-> Browser
# DBServer(MariaDB) <-> Tool(HeidiSQL)
#
#
#
# (maria)DB 에 명령을 내리는 방법이 SQL.
#
# 기능 4가지
# Create
# Read
# Update
# Delete
#
# ![image.png](attachment:image.png)

# %%
now_page = 10
show_cnt = 10 # 한페이지에 있는 개수

# %%
#0~5


end = now_page *show_cnt
start = end -show_cnt
print(start,end)
# Out:
# 90 100
